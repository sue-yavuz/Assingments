# %% [markdown]
# # Statistics Assignment-3 (Hypothesis Tests)

# %%
import numpy as np
import pandas as pd
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# EXERCISE 1. The hourly wages in a particular industry are normally distributed with mean 13.20andstandarddeviation 2.50. A company in this industry employs 40 workers, paying them an average of $12.20 per hour. Can this company be accused of paying substandard wages? Use an α = .01 level test. (Wackerly, Ex.10.18)
#
# CHECK: statistic: -2.5298221281347035, pvalue= 0.005706018193000826

# %%
# H0: mean(mu) = 13.20  (standart)
# H1: mean(mu) < 13.20  (substandart) 

mu = 13.20
s = 2.50
xbar = 12.20

z_score = (mu - xbar) / (s/np.sqrt(40))
z_score
# Out:
# 2.5298221281347035

# %% [markdown]
# left tail = -2.5298221281347035

# %%
upper = 1 - stats.norm.cdf(z_score)
upper
# Out:
# 0.005706018193000872

# %%
alpha = 0.01

if upper < alpha:
    print("Reject the null")
else:
    print("Fail to reject the null")
# Out:
# Reject the null

# %% [markdown]
# EXERCISE 2.Shear strength measurements derived from unconfined compression tests for two types of soils gave the results shown in the following document (measurements in tons per square foot). Do the soils appear to differ with respect to average shear strength, at the 1% significance level?
#
# Results for two type of soils
#
# CHECK: statistic: 5.1681473319343345, pvalue= 2.593228732352821e-06

# %%
df_pisa = pd.read_csv('soil - Sheet1.csv')
df_pisa
# Out:
#     Soil1  Soil2
# 0   1.442  1.364
# 1   1.943  1.878
# 2   1.110  1.337
# 3   1.912  1.828
# 4   1.553  1.371
# 5   1.641  1.428
# 6   1.499  1.119
# 7   1.347  1.373
# 8   1.685  1.589
# 9   1.578  1.714
# 10  1.866  1.260
# 11  1.653  1.492
# 12  1.665  1.395
# 13  1.640  1.778
# 14  1.976  1.611
# 15  1.754  1.202
# 16  1.589  1.542
# 17  1.976  1.094
# 18  1.863  1.557
# 19  1.932  1.053
# 20  1.570  1.183
# 21  1.613  1.367
# 22  2.054  1.144
# 23  1.550  1.151
# 24  1.714  1.561
# 25  1.896  1.192
# 26  1.737  1.489
# 27  1.740  1.379
# 28  1.708  1.501
# 29  1.548  1.277
# 30    NaN  1.593
# 31    NaN  1.172
# 32    NaN  1.510
# 33    NaN  1.740
# 34    NaN  1.355

# %%
print(df1.Soil1.mean())
print(df1.Soil2.mean())
# Out:
# 1.6918
# 1.4171142857142855

# %%
df1.Soil1.isna().sum()
# Out:
# 5

# %%
df1.Soil2.isna().sum()
# Out:
# 0

# %% [markdown]
# H0: mu1 = mu2 \
# H1: mu1 != mu2

# %%
stats.levene(df1.dropna()['Soil1'], df1['Soil2'])
# Out:
# LeveneResult(statistic=0.31486292982090475, pvalue=0.5767018253541134)

# %% [markdown]
# H0 rejected

# %%
stats.ttest_ind(df1.dropna()['Soil1'], df1['Soil2'], equal_var=True)
# Out:
# Ttest_indResult(statistic=5.1681473319343345, pvalue=2.593228732352821e-06)

# %%
alpha = 0.01

if indTest.pvalue < alpha:
    print("Reject the null")
else:
    print("Fail to reject the null")
# Out:
# Reject the null

# %% [markdown]
# EXERCISE 3. The following dataset is based on data provided by the World Bank (https://datacatalog.worldbank.org/dataset/education-statistics). World Bank Edstats. 2015 PISA Test Dataset
#
# Get descriptive statistics (the central tendency, dispersion and shape of a dataset’s distribution) for each continent group (AS, EU, AF, NA, SA, OC). Determine whether there is any difference (on the average) for the math scores among European (EU) and Asian (AS) countries (assume normality and equal variances). Draw side-by-side box plots. CHECK: statistic=0.870055317967983, pvalue=0.38826888111307345

# %%
df_pisa = pd.read_csv("2015 PISA Test - Sheet1.csv")
df_pisa
# Out:
#    Country Code Continent_Code  internet_users_per_100      Math   Reading  \
# 0           ALB             EU               63.252933  413.1570  405.2588
# 1           ARE             AS               90.500000  427.4827  433.5423
# 2           ARG             SA               68.043064  409.0333  425.3031
# 3           AUS             OC               84.560519  493.8962  502.9006
# 4           AUT             EU               83.940142  496.7423  484.8656
# ..          ...            ...                     ...       ...       ...
# 65          TUN             AF               48.519836  366.8180  361.0555
# 66          TUR             EU               53.744979  420.4540  428.3351
# 67          URY             SA               64.600000  417.9919  436.5721
# 68          USA            NaN               74.554202  469.6285  496.9351
# 69          VNM             AS               43.500000  494.5183  486.7738
#
#      Science
# 0   427.2250
# 1   436.7311
# 2   432.2262
# ...

# %%
df_pisa.describe().T
# Out:
#                         count        mean        std         min         25%  \
# internet_users_per_100   70.0   71.973099  16.390632   21.976068   60.899020
# Math                     70.0  460.971557  53.327205  327.702000  417.416075
# Reading                  70.0  460.997291  49.502679  346.549000  426.948625
# Science                  70.0  465.439093  48.397254  331.638800  425.923375
#
#                               50%         75%       max
# internet_users_per_100   72.99935   85.026763   98.2000
# Math                    477.60715  500.482925  564.1897
# Reading                 480.19985  499.687475  535.1002
# Science                 475.40005  502.431250  555.5747

# %%
df_pisa.groupby("Continent_Code").describe().T
# Out:
# Continent_Code                        AF          AS          EU          OC  \
# internet_users_per_100 count    2.000000   17.000000   37.000000    2.000000
#                        mean    43.359918   68.455613   77.274888   86.391704
#                        std      7.297226   21.086060   12.425773    2.589686
#                        min     38.200000   21.976068   53.744979   84.560519
#                        25%     40.779959   50.300000   68.632900   85.476112
#                        50%     43.359918   74.000000   76.184000   86.391704
#                        75%     45.939877   84.948353   87.479056   87.307296
#                        max     48.519836   92.884826   98.200000   88.222889
# Math                   count    2.000000   17.000000   37.000000    2.000000
#                        mean   363.212100  466.216647  477.981449  494.559750
#                        std      5.099513   64.356490   35.150403    0.938401
# ...

# %%
dfmath = df_pisa.groupby("Continent_Code").describe()["Math"]
dfmath
# Out:
#                 count        mean        std       min         25%        50%  \
# Continent_Code
# AF                2.0  363.212100   5.099513  359.6062  361.409150  363.21210
# AS               17.0  466.216647  64.356490  380.2590  403.833200  459.81600
# EU               37.0  477.981449  35.150403  371.3114  464.040100  489.72870
# OC                2.0  494.559750   0.938401  493.8962  494.227975  494.55975
# SA                7.0  402.887700  18.128894  377.0695  388.102200  409.03330
#
#                        75%       max
# Continent_Code
# AF              365.015050  366.8180
# AS              531.296100  564.1897
# EU              503.722000  521.2506
# OC              494.891525  495.2233
# SA              417.617650  422.6714

# %% [markdown]
# MATH

# %%
mean = df_pisa.Math.mean()
median = df_pisa.Math.median()
mode = df_pisa.Math.mode()

plt.figure(figsize=(10,5))
plt.hist(df2.Math,bins=20,color='lightgrey')
plt.axvline(mean,color='red',label='Mean')
plt.axvline(median,color='blue',label='Median')
plt.axvline(mode[0],color='grey',label='Mode')
plt.xlabel('Math')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# READING

# %%
mean = df_pisa.Reading.mean()
median = df_pisa.Reading.median()
mode = df_pisa.Reading.mode()

plt.figure(figsize=(10,5))
plt.hist(df2.Reading,bins=20,color='lightgrey')
plt.axvline(mean,color='red',label='Mean')
plt.axvline(median,color='blue',label='Median')
plt.axvline(mode[0],color='grey',label='Mode')
plt.xlabel('Reading')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %% [markdown]
# SCIENCE

# %%
mean = df_pisa.Science.mean()
median = df_pisa.Science.median()
mode = df_pisa.Science.mode()

plt.figure(figsize=(10,5))
plt.hist(df2.Science,bins=20,color='lightgrey')
plt.axvline(mean,color='red',label='Mean')
plt.axvline(median,color='blue',label='Median')
plt.axvline(mode[0],color='grey',label='Mode')
plt.xlabel('Science')
plt.ylabel('Frequency')
plt.legend()

plt.show()

# %%
df_pisa[(df_pisa['Continent_Code'] == "AS") | (df_pisa['Continent_Code'] == "EU")][['Math','Continent_Code']]
# Out:
#         Math Continent_Code
# 0   413.1570             EU
# 1   427.4827             AS
# 4   496.7423             EU
# 5   506.9844             EU
# 6   441.1899             EU
# 9   521.2506             EU
# 11  531.2961             AS
# 14  437.1443             EU
# 15  492.3254             EU
# 16  505.9713             EU
# 17  511.0876             EU
# 20  485.8432             EU
# 21  519.5291             EU
# 22  511.0769             EU
# 23  492.9204             EU
# 24  492.4785             EU
# 25  403.8332             AS
# 26  453.6299             EU
# 27  547.9310             AS
# 28  464.0401             EU
# 29  476.8309             EU
# 30  386.1096             AS
# 31  503.7220             EU
# 32  488.0332             EU
# 33  469.6695             AS
# 34  489.7287             EU
# 35  380.2590             AS
# 36  532.4399             AS
# 37  459.8160             AS
# 38  524.1062             AS
# 39  396.2497             AS
# 40  478.3834             EU
# ...

# %%
sns.boxplot(y='Math', x='Continent_Code', data = df_pisa[(df_pisa['Continent_Code'] == "AS") | (df_pisa['Continent_Code'] == "EU")][['Math','Continent_Code']]);

# %%
EU = df_pisa[df_pisa['Continent_Code'] == "EU"]['Math']
EU
# Out:
# 0     413.1570
# 4     496.7423
# 5     506.9844
# 6     441.1899
# 9     521.2506
# 14    437.1443
# 15    492.3254
# 16    505.9713
# 17    511.0876
# 20    485.8432
# 21    519.5291
# 22    511.0769
# 23    492.9204
# 24    492.4785
# 26    453.6299
# 28    464.0401
# 29    476.8309
# 31    503.7220
# 32    488.0332
# 34    489.7287
# 40    478.3834
# 41    485.7706
# 42    482.3051
# 44    419.6635
# 46    371.3114
# 47    478.6448
# 48    417.9341
# 50    512.2528
# 51    501.7298
# 54    504.4693
# 55    491.6270
# 57    443.9543
# 58    494.0600
# 60    475.2301
# 61    509.9196
# 62    493.9181
# 66    420.4540
# Name: Math, dtype: float64

# %%
AS = df_pisa[df_pisa['Continent_Code'] == "AS"]['Math']
AS
# Out:
# 1     427.4827
# 11    531.2961
# 25    403.8332
# 27    547.9310
# 30    386.1096
# 33    469.6695
# 35    380.2590
# 36    532.4399
# 37    459.8160
# 38    524.1062
# 39    396.2497
# 43    543.8078
# 49    446.1098
# 56    402.4007
# 59    564.1897
# 63    415.4638
# 69    494.5183
# Name: Math, dtype: float64

# %% [markdown]
# H0: mu1 = mu2 \
# H1: mu1 != mu2

# %%
indTest = stats.ttest_ind(EU, AS,equal_var=True)
indTest
# Out:
# Ttest_indResult(statistic=0.870055317967983, pvalue=0.38826888111307345)

# %%
alpha = 0.05

if indTest.pvalue < alpha:
    print("Reject the null")
else:
    print("Fail to reject the null")
# Out:
# Fail to reject the null
